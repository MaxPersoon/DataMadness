# %%
import pandas as pd

# %%
tweets = pd.read_json("user-tweets.json",lines = True)
tweets.head()
# Out:
#                             _type  \
# 0  snscrape.modules.twitter.Tweet
# 1  snscrape.modules.twitter.Tweet
# 2  snscrape.modules.twitter.Tweet
# 3  snscrape.modules.twitter.Tweet
# 4  snscrape.modules.twitter.Tweet
#
#                                                  url  \
# 0  https://twitter.com/alpere75/status/1495463708...
# 1  https://twitter.com/lyfewavs/status/1495463706...
# 2  https://twitter.com/GeneraalSpoor4a/status/149...
# 3  https://twitter.com/DerekPederson3/status/1495...
# 4  https://twitter.com/VaccineHistory/status/1495...
#
#                        date  \
# 0 2022-02-20 18:21:47+00:00
# 1 2022-02-20 18:21:46+00:00
# 2 2022-02-20 18:21:45+00:00
# 3 2022-02-20 18:21:41+00:00
# 4 2022-02-20 18:21:40+00:00
#
#                                              content  \
# 0       Good fight #PS4share https://t.co/rpF16fUrbY
# 1  What is even the point of discussing science, ...
# 2  So, what's up with that injection that doesn't...
# ...

# %%
tweets.shape
# Out:
# (10000, 28)

# %%
tweets.columns.values
# Out:
# array(['_type', 'url', 'date', 'content', 'renderedContent', 'id', 'user',
#        'replyCount', 'retweetCount', 'likeCount', 'quoteCount',
#        'conversationId', 'lang', 'source', 'sourceUrl', 'sourceLabel',
#        'outlinks', 'tcooutlinks', 'media', 'retweetedTweet',
#        'quotedTweet', 'inReplyToTweetId', 'inReplyToUser',
#        'mentionedUsers', 'coordinates', 'place', 'hashtags', 'cashtags'],
#       dtype=object)

# %%
## NaN values under the entire dataset 
tweets.isnull().sum().sum()
# Out:
# 92230

# %%
user_list = tweets["user"].tolist()
assert len(user_list) == 10000

# %%
#create a new dataframe containing user information of owners of each tweet 
users = pd.DataFrame(user_list)
users
# Out:
#                               _type         username                   id  \
# 0     snscrape.modules.twitter.User         alpere75             39955437
# 1     snscrape.modules.twitter.User         lyfewavs  1410232968375853067
# 2     snscrape.modules.twitter.User  GeneraalSpoor4a   817733760158416898
# 3     snscrape.modules.twitter.User   DerekPederson3   773707019425579009
# 4     snscrape.modules.twitter.User   VaccineHistory           3377581605
# ...                             ...              ...                  ...
# 9995  snscrape.modules.twitter.User     blazingcajun  1432689646903906312
# 9996  snscrape.modules.twitter.User           Tsartw             88722266
# 9997  snscrape.modules.twitter.User   HRisInnovative            210695187
# 9998  snscrape.modules.twitter.User      sweetdoodmd             49896058
# 9999  snscrape.modules.twitter.User       rapidbaldy  1346848353150259201
#
#                                    displayname  \
# ...

# %%
users.shape
# Out:
# (10000, 23)

# %%
# see if each tweet is owned by a different user 
users["id"].nunique()
# Out:
# 7473

# %%
print("Number of null values in column location :  ",users["location"].isna().sum())
print(users["location"].unique())
# Out:
# Number of null values in column location :   0
# ['' ' Ontario, Canada ' '🇺🇸 Ohio' ... 'Seawind - Blue Water Cruiser'
#  '늘 고맙고 사랑해 ♡︎' 'Veracruz, México.']
